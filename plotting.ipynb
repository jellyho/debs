# %%
from utils.wandb_utils import plot_and_save_from_wandb

# %%
configs = {
    "WANDB_ENTITY" : "jellyho_",
    "WANDB_PROJECT" : "MFQ",
    "x_key": "_step",
    # "y_key": "latent/z_norm",
    "y_key": "eval/success",
    "title": "Average_SR_Comparison_Latent",

    "configs":[
        {
            "filters": {
                "group": "25122001:meanflowq",      # 실험 그룹명
                "config.horizon_length": 5,       # [중요] horizon이 5인 것만!
                "config.agent.rl_method": "iql", # ddpg인 것만!
                "config.agent.extract_method": "awr", # ddpg인 것만!
                # "config.agent.latent_dist" : "normal",
                "state": "finished"             # 완료된 것만 (필요시 주석 해제)
            },
            "prefix":"iql-awr",
            "group_by": "config.agent.latent_dist",  # config.task_name도 가능
            "select_values": None,
        },
        {
            "filters": {
                "group": "25122001:meanflowq",      # 실험 그룹명
                "config.horizon_length": 5,       # [중요] horizon이 5인 것만!
                "config.agent.rl_method": "iql", # ddpg인 것만!
                "config.agent.extract_method": "awr", # ddpg인 것만!
                # "config.agent.latent_dist" : "normal",
                "state": "finished"             # 완료된 것만 (필요시 주석 해제)
            },
            "prefix":"iql-ddpg",
            "group_by": "config.agent.latent_dist",  # config.task_name도 가능
            "select_values": None,
        },
        {
            "filters": {
                "group": "25122001:meanflowq",      # 실험 그룹명
                "config.horizon_length": 5,       # [중요] horizon이 5인 것만!
                "config.agent.rl_method": "ddpg", # ddpg인 것만!
                "config.agent.extract_method": "ddpg", # ddpg인 것만!
                # "config.agent.latent_dist" : "normal",
                "state": "finished"             # 완료된 것만 (필요시 주석 해제)
            },
            "prefix":"ddpg-ddpg",
            "group_by": "config.agent.latent_dist",  # config.task_name도 가능
            "select_values": None,
        },
    ],
}
plot_and_save_from_wandb(configs)

# %%
configs = {
    "WANDB_ENTITY" : "jellyho_",
    "WANDB_PROJECT" : "MFQ",
    "x_key": "_step",
    # "y_key": "latent/z_norm",
    "y_key": "eval/success",
    "title": "Average_SR_Comparison_normal",

    "configs":[
        {
            "filters": {
                "group": "25122203_scene_new:meanflowq",      # 실험 그룹명
                "config.horizon_length": 5,       # [중요] horizon이 5인 것만!
                # "config.agent.rl_method": "iql", # ddpg인 것만!
                # "config.agent.extract_method": "awr", # ddpg인 것만!
                # "config.agent.latent_dist" : "normal",
                "state": "finished"             # 완료된 것만 (필요시 주석 해제)
            },
            "prefix":"onestep",
            "state",  # config.task_name도 가능
            "select_values": None,
        },
        {
            "filters": {
                "group": "25122201_okay_critic:meanflowq",      # 실험 그룹명
                "config.horizon_length": 5,       # [중요] horizon이 5인 것만!
                # "config.agent.rl_method": "iql", # ddpg인 것만!
                # "config.agent.extract_method": "awr", # ddpg인 것만!
                # "config.agent.latent_dist" : "normal",
                "state": "finished"             # 완료된 것만 (필요시 주석 해제)
            },
            "prefix":"onestep_ddpg",
            "group_by": "config.agent_nam",  # config.task_name도 가능
            "select_values": None,
        },
    ],
}
plot_and_save_from_wandb(configs)
# Out:
# Fetching runs with filters: {'group': '25122203_scene_new:meanflowq', 'config.horizon_length': 5, 'state': 'finished'}...
# Found 15 runs.
# 100%|██████████| 15/15 [00:04<00:00,  3.19it/s]
# Fetching runs with filters: {'group': '25122201_okay_critic:meanflowq', 'config.horizon_length': 5, 'state': 'finished'}...
# Found 30 runs.
# 100%|██████████| 30/30 [00:10<00:00,  2.96it/s]

# %%
configs = {
    "WANDB_ENTITY" : "jellyho_",
    "WANDB_PROJECT" : "MFQ",
    "x_key": "_step",
    # "y_key": "latent/z_norm",
    "y_key": "eval/success",
    "title": "Average_SR_Comparison_Baselines",

    "configs":[
        {
            "filters": {
                "group": "25122302_onestep_ddpg_tuning:meanflowq",      # 실험 그룹명
                # "config.horizon_length": 5,       # [중요] horizon이 5인 것만!
                # "config.agent.rl_method": "iql", # ddpg인 것만!
                # "config.agent.extract_method": "awr", # ddpg인 것만!
                # "config.agent.latent_dist" : "normal",
                "state": "finished"             # 완료된 것만 (필요시 주석 해제)
            },
            "prefix":"onestep_latent_ddpg",
            "group_by": "config.horizon_length",  # config.task_name도 가능
            "select_values": None,
        },
        {
            "filters": {
                "group": "25122303_onestep_ddpg_tuning:meanflowqonestep",      # 실험 그룹명
                # "config.horizon_length": 5,       # [중요] horizon이 5인 것만!
                # "config.agent.rl_method": "iql", # ddpg인 것만!
                # "config.agent.extract_method": "awr", # ddpg인 것만!
                # "config.agent.latent_dist" : "normal",
                "state": "finished"             # 완료된 것만 (필요시 주석 해제)
            },
            "prefix":"onestep_ddpg",
            "group_by": "config.horizon_length",  # config.task_name도 가능
            "select_values": None,
        },
    ],
}
plot_and_save_from_wandb(configs)
# Out:
# Fetching runs with filters: {'group': '25122302_onestep_ddpg_tuning:meanflowq', 'state': 'finished'}...
# Found 72 runs.
#   7%|▋         | 5/72 [00:01<00:23,  2.80it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 38
#       1 configs = {
#       2     "WANDB_ENTITY" : "jellyho_",
#       3     "WANDB_PROJECT" : "MFQ",
#    (...)
#      36     ],
#      37 }
# ---> 38 plot_and_save_from_wandb(configs)
#
# File ~/Offline/debs/utils/wandb_utils.py:142, in plot_and_save_from_wandb(PLOT_CONFIG)
#     139 dfs = []
#     141 for config in PLOT_CONFIG['configs']:
# --> 142     df = get_filtered_data(PLOT_CONFIG['WANDB_ENTITY'], PLOT_CONFIG['WANDB_PROJECT'], config, x_key, y_key)
#     143     dfs.append(df)
#     145 if len(dfs) > 0:
#
# File ~/Offline/debs/utils/wandb_utils.py:44, in get_filtered_data(entity, project, config, x_key, y_key)
# ...

# %%
for task in ['scene-play', 'puzzle-3x3-play', 'cube-double-play']:
    configs = {
        "WANDB_ENTITY" : "jellyho_",
        "WANDB_PROJECT" : "MFQ",
        "x_key": "_step",
        # "y_key": "latent/z_norm",
        "y_key": "eval/success",
        "title": f"Average_SR_Alpha_Tuning_{task}",

        "configs" : [
            {
                "filters": {
                    "group": "25122303_onestep_ddpg_tuning:meanflowqonestep",      # 실험 그룹명
                    # "config.horizon_length": 5,       # [중요] horizon이 5인 것만!
                    # "config.agent.rl_method": "iql", # ddpg인 것만!
                    # "config.agent.extract_method": "awr", # ddpg인 것만!
                    # "config.agent.latent_dist" : "normal",
                    "config.task_name": f"{task}",
                    "state": "finished"             # 완료된 것만 (필요시 주석 해제)
                },
                "prefix":"onestep_ddpg",
                "group_by": "config.agent.alpha",  # config.task_name도 가능
                "select_values": None,
            },
        ],
    }
    plot_and_save_from_wandb(configs)
# Out:
# Fetching runs with filters: {'group': '25122303_onestep_ddpg_tuning:meanflowqonestep', 'config.task_name': 'scene-play', 'state': 'finished'}...
# Found 24 runs.
# 100%|██████████| 24/24 [00:06<00:00,  3.63it/s]
# Fetching runs with filters: {'group': '25122303_onestep_ddpg_tuning:meanflowqonestep', 'config.task_name': 'puzzle-3x3-play', 'state': 'finished'}...
# Found 24 runs.
# 100%|██████████| 24/24 [00:07<00:00,  3.06it/s]
# Fetching runs with filters: {'group': '25122303_onestep_ddpg_tuning:meanflowqonestep', 'config.task_name': 'cube-double-play', 'state': 'finished'}...
# Found 24 runs.
# 100%|██████████| 24/24 [00:07<00:00,  3.16it/s]

# %%
for task in ['scene-play', 'puzzle-3x3-play', 'cube-double-play']:
    configs = {
        "WANDB_ENTITY" : "jellyho_",
        "WANDB_PROJECT" : "MFQ",
        "x_key": "_step",
        # "y_key": "latent/z_norm",
        "y_key": "eval/success",
        "title": f"Average_SR_Alpha_Tuning_latent_{task}",

        "configs" : [
            {
                "filters": {
                    "group": "25122302_onestep_ddpg_tuning:meanflowq",      # 실험 그룹명
                    # "config.horizon_length": 5,       # [중요] horizon이 5인 것만!
                    # "config.agent.rl_method": "iql", # ddpg인 것만!
                    # "config.agent.extract_method": "awr", # ddpg인 것만!
                    # "config.agent.latent_dist" : "normal",
                    "config.task_name": f"{task}",
                    "state": "finished"             # 완료된 것만 (필요시 주석 해제)
                },
                "prefix":"onestep_ddpg",
                "group_by": "config.agent.alpha",  # config.task_name도 가능
                "select_values": None,
            },
        ],
    }
    plot_and_save_from_wandb(configs)
# Out:
# Fetching runs with filters: {'group': '25122302_onestep_ddpg_tuning:meanflowq', 'config.task_name': 'scene-play', 'state': 'finished'}...
# Found 24 runs.
# 100%|██████████| 24/24 [00:06<00:00,  3.51it/s]
# Fetching runs with filters: {'group': '25122302_onestep_ddpg_tuning:meanflowq', 'config.task_name': 'puzzle-3x3-play', 'state': 'finished'}...
# Found 24 runs.
# 100%|██████████| 24/24 [00:07<00:00,  3.20it/s]
# Fetching runs with filters: {'group': '25122302_onestep_ddpg_tuning:meanflowq', 'config.task_name': 'cube-double-play', 'state': 'finished'}...
# Found 24 runs.
# 100%|██████████| 24/24 [00:07<00:00,  3.15it/s]

# %%
for task in ['scene-play', 'puzzle-3x3-play', 'cube-double-play']:
    configs = {
        "WANDB_ENTITY" : "jellyho_",
        "WANDB_PROJECT" : "MFQ",
        "x_key": "_step",
        # "y_key": "latent/z_norm",
        "y_key": "eval/success",
        "title": f"Average_SR_Alpha_Tuning_ours_{task}",

        "configs" : [
            {
                "filters": {
                    "group": "25122304_ddpg_tuning:meanflowq",      # 실험 그룹명
                    # "config.horizon_length": 5,       # [중요] horizon이 5인 것만!
                    # "config.agent.rl_method": "iql", # ddpg인 것만!
                    # "config.agent.extract_method": "awr", # ddpg인 것만!
                    # "config.agent.latent_dist" : "normal",
                    "config.task_name": f"{task}",
                    "state": "finished"             # 완료된 것만 (필요시 주석 해제)
                },
                "prefix":"onestep_ddpg",
                "group_by": "config.agent.alpha",  # config.task_name도 가능
                "select_values": None,
            },
        ],
    }
    plot_and_save_from_wandb(configs)
# Out:
# Fetching runs with filters: {'group': '25122304_ddpg_tuning:meanflowq', 'config.task_name': 'scene-play', 'state': 'finished'}...
# Found 22 runs.
# 100%|██████████| 22/22 [00:07<00:00,  3.06it/s]
# Fetching runs with filters: {'group': '25122304_ddpg_tuning:meanflowq', 'config.task_name': 'puzzle-3x3-play', 'state': 'finished'}...
# Found 20 runs.
# 100%|██████████| 20/20 [00:06<00:00,  3.32it/s]
# Fetching runs with filters: {'group': '25122304_ddpg_tuning:meanflowq', 'config.task_name': 'cube-double-play', 'state': 'finished'}...
# Found 21 runs.
# 100%|██████████| 21/21 [00:07<00:00,  2.95it/s]

# %%
for task in ['scene-play', 'puzzle-3x3-play', 'cube-double-play']:
    configs = {
        "WANDB_ENTITY" : "jellyho_",
        "WANDB_PROJECT" : "MFQ",
        "x_key": "_step",
        # "y_key": "latent/z_norm",
        "y_key": "eval/success",
        "title": f"Average_SR_Alpha_Tuning_onestep_latent_normal_{task}",

        "configs" : [
            {
                "filters": {
                    "group": "25122305_ddpg_tuning:meanflowq",      # 실험 그룹명
                    # "config.horizon_length": 5,       # [중요] horizon이 5인 것만!
                    # "config.agent.rl_method": "iql", # ddpg인 것만!
                    # "config.agent.extract_method": "awr", # ddpg인 것만!
                    # "config.agent.latent_dist" : "normal",
                    "config.task_name": f"{task}",
                    "state": "finished"             # 완료된 것만 (필요시 주석 해제)
                },
                "prefix":"onestep_latent_ddpg_sphere",
                "group_by": "config.agent.alpha",  # config.task_name도 가능
                "select_values": None,
            },
        ],
    }
    plot_and_save_from_wandb(configs)
# Out:
# Fetching runs with filters: {'group': '25122305_ddpg_tuning:meanflowq', 'config.task_name': 'scene-play', 'state': 'finished'}...
# Found 24 runs.
# 100%|██████████| 24/24 [00:07<00:00,  3.43it/s]
# Fetching runs with filters: {'group': '25122305_ddpg_tuning:meanflowq', 'config.task_name': 'puzzle-3x3-play', 'state': 'finished'}...
# Found 24 runs.
# 100%|██████████| 24/24 [00:07<00:00,  3.39it/s]
# Fetching runs with filters: {'group': '25122305_ddpg_tuning:meanflowq', 'config.task_name': 'cube-double-play', 'state': 'finished'}...
# Found 24 runs.
# 100%|██████████| 24/24 [00:07<00:00,  3.39it/s]

# %%
for task in ['scene-play', 'puzzle-3x3-play', 'cube-double-play']:
    configs = {
        "WANDB_ENTITY" : "jellyho_",
        "WANDB_PROJECT" : "MFQ",
        "x_key": "_step",
        # "y_key": "latent/z_norm",
        "y_key": "eval/success",
        "title": f"Average_SR_Alpha_Tuning_onestep_distill_sphere_{task}",

        "configs" : [
            {
                "filters": {
                    "group": "25122401_ddpg_onestep_tuning:meanflowqonestep",      # 실험 그룹명
                    # "config.horizon_length": 5,       # [중요] horizon이 5인 것만!
                    # "config.agent.rl_method": "iql", # ddpg인 것만!
                    # "config.agent.extract_method": "awr", # ddpg인 것만!
                    # "config.agent.latent_dist" : "normal",
                    "config.task_name": f"{task}",
                    # "state": "finished"             # 완료된 것만 (필요시 주석 해제)
                },
                "prefix":"onestep_latent_ddpg_sphere",
                "group_by": "config.agent.alpha",  # config.task_name도 가능
                "select_values": None,
            },
        ],
    }
    plot_and_save_from_wandb(configs)
# Out:
# Fetching runs with filters: {'group': '25122401_ddpg_onestep_tuning:meanflowqonestep', 'config.task_name': 'scene-play'}...
# Found 24 runs.
# 100%|██████████| 24/24 [00:08<00:00,  2.77it/s]
# Fetching runs with filters: {'group': '25122401_ddpg_onestep_tuning:meanflowqonestep', 'config.task_name': 'puzzle-3x3-play'}...
# Found 24 runs.
# 100%|██████████| 24/24 [00:05<00:00,  4.01it/s]
# Fetching runs with filters: {'group': '25122401_ddpg_onestep_tuning:meanflowqonestep', 'config.task_name': 'cube-double-play'}...
# Found 24 runs.
# 100%|██████████| 24/24 [00:08<00:00,  2.69it/s]

# %%
configs = {
    "WANDB_ENTITY" : "jellyho_",
    "WANDB_PROJECT" : "MFQ",
    "x_key": "_step",
    # "y_key": "latent/z_norm",
    "y_key": "eval/success",
    "title": f"Average_SR_QC_MFQL_normal",

    "configs" : [
        {
            "filters": {
                "group": "25122403_QC_MFQL_Final:meanflowqonestep",      # 실험 그룹명
                # "config.horizon_length": 5,       # [중요] horizon이 5인 것만!
                # "config.agent.rl_method": "iql", # ddpg인 것만!
                # "config.agent.extract_method": "awr", # ddpg인 것만!
                "config.agent.latent_dist" : "normal",
                # "config.task_name": f"{task}",
                # "state": "finished"             # 완료된 것만 (필요시 주석 해제)
            },
            "prefix":"QC-MFQL",
            "group_by": "config.task_name",  # config.task_name도 가능
            "select_values": None,
        },
    ],
}
plot_and_save_from_wandb(configs)
# Out:
# Fetching runs with filters: {'group': '25122403_QC_MFQL_Final:meanflowqonestep', 'config.agent.latent_dist': 'normal'}...
# Found 45 runs.
# 100%|██████████| 45/45 [00:12<00:00,  3.50it/s]

# %%
configs = {
    "WANDB_ENTITY" : "jellyho_",
    "WANDB_PROJECT" : "MFQ",
    "x_key": "_step",
    # "y_key": "latent/z_norm",
    "y_key": "eval/success",
    "title": f"Average_SR_QC_MFQL_sphere",

    "configs" : [
        {
            "filters": {
                "group": "25122403_QC_MFQL_Final:meanflowqonestep",      # 실험 그룹명
                # "config.horizon_length": 5,       # [중요] horizon이 5인 것만!
                # "config.agent.rl_method": "iql", # ddpg인 것만!
                # "config.agent.extract_method": "awr", # ddpg인 것만!
                "config.agent.latent_dist" : "sphere",
                # "config.task_name": f"{task}",
                # "state": "finished"             # 완료된 것만 (필요시 주석 해제)
            },
            "prefix":"QC-MFQL",
            "group_by": "config.task_name",  # config.task_name도 가능
            "select_values": None,
        },
    ],
}
plot_and_save_from_wandb(configs)
# Out:
# Fetching runs with filters: {'group': '25122403_QC_MFQL_Final:meanflowqonestep', 'config.agent.latent_dist': 'sphere'}...
# Found 45 runs.
# 100%|██████████| 45/45 [00:13<00:00,  3.30it/s]

# %%
configs = {
    "WANDB_ENTITY" : "jellyho_",
    "WANDB_PROJECT" : "MFQ",
    "x_key": "_step",
    # "y_key": "latent/z_norm",
    "y_key": "eval/success",
    "title": f"Average_SR_LQL_distill_normal",

    "configs" : [
        {
            "filters": {
                "group": "25122404_LQL_Final:meanflowq",      # 실험 그룹명
                # "config.horizon_length": 5,       # [중요] horizon이 5인 것만!
                # "config.agent.rl_method": "iql", # ddpg인 것만!
                # "config.agent.extract_method": "awr", # ddpg인 것만!
                "config.agent.latent_dist" : "normal",
                # "config.task_name": f"{task}",
                # "state": "finished"             # 완료된 것만 (필요시 주석 해제)
            },
            "prefix":"LQL_distill",
            "group_by": "config.task_name",  # config.task_name도 가능
            "select_values": None,
        },
    ],
}
plot_and_save_from_wandb(configs)
# Out:
# Fetching runs with filters: {'group': '25122404_LQL_Final:meanflowq', 'config.agent.latent_dist': 'normal'}...
# Found 45 runs.
# 100%|██████████| 45/45 [00:14<00:00,  3.02it/s]

# %%
configs = {
    "WANDB_ENTITY" : "jellyho_",
    "WANDB_PROJECT" : "MFQ",
    "x_key": "_step",
    # "y_key": "latent/z_norm",
    "y_key": "eval/success",
    "title": f"Average_SR_LQL_distill_sphere",

    "configs" : [
        {
            "filters": {
                "group": "25122404_LQL_Final:meanflowq",      # 실험 그룹명
                # "config.horizon_length": 5,       # [중요] horizon이 5인 것만!
                # "config.agent.rl_method": "iql", # ddpg인 것만!
                # "config.agent.extract_method": "awr", # ddpg인 것만!
                "config.agent.latent_dist" : "sphere",
                # "config.task_name": f"{task}",
                # "state": "finished"             # 완료된 것만 (필요시 주석 해제)
            },
            "prefix":"LQL_distill",
            "group_by": "config.task_name",  # config.task_name도 가능
            "select_values": None,
        },
    ],
}
plot_and_save_from_wandb(configs)
# Out:
# Fetching runs with filters: {'group': '25122404_LQL_Final:meanflowq', 'config.agent.latent_dist': 'sphere'}...
# Found 45 runs.
# 100%|██████████| 45/45 [00:14<00:00,  3.19it/s]

# %%
configs = {
    "WANDB_ENTITY" : "jellyho_",
    "WANDB_PROJECT" : "MFQ",
    "x_key": "_step",
    # "y_key": "latent/z_norm",
    "y_key": "eval/success",
    "title": "Average_SR_LQL_Normal",

    "configs":[
        {
            "filters": {
                "group": "25122407_LQL_Normal_FINAL:meanflowq",      # 실험 그룹명
                # "config.horizon_length": 5,       # [중요] horizon이 5인 것만!
                # "config.agent.rl_method": "iql", # ddpg인 것만!
                # "config.agent.extract_method": "awr", # ddpg인 것만!
                # "config.agent.latent_dist" : "normal",
                "state": "finished"             # 완료된 것만 (필요시 주석 해제)
            },
            "prefix":"LQL-Normal",
            "group_by": "config.task_name",  # config.task_name도 가능
            "select_values": None,
        },
    ],
}
plot_and_save_from_wandb(configs)

# %%
configs = {
    "WANDB_ENTITY" : "jellyho_",
    "WANDB_PROJECT" : "MFQ",
    "x_key": "_step",
    # "y_key": "latent/z_norm",
    "y_key": "eval/success",
    "title": "OGBench_5_task_results_(Sphere)",

    "configs":[
        {
            "filters": {
                "group": "25122601_FINAL_MF:meanflow",      # 실험 그룹명
                "config.horizon_length": 5,       # [중요] horizon이 5인 것만!
                "config.agent.latent_dist" : "sphere",
                "state": "finished",             # 완료된 것만 (필요시 주석 해제)
                # "seed": [100, 200, 300]
            },
            "prefix":"sphere",
            "group_by": "config.agent.agent_name",  # config.task_name도 가능
            "select_values": None,
        },
        {
            "filters": {
                "group": "25122601_FINAL_F:flow",      # 실험 그룹명
                "config.horizon_length": 5,       # [중요] horizon이 5인 것만!
                "config.agent.latent_dist" : "sphere",
                "state": "finished",
                # "seed": [100, 200, 300]
            },
            "prefix":"sphere",
            "group_by": "config.agent.agent_name",  # config.task_name도 가능
            "select_values": None,
        },
        {
            "filters": {
                "group": "25122605_LQL_FINAL:meanflowq",      # 실험 그룹명
                "config.horizon_length": 5,       # [중요] horizon이 5인 것만!
                "config.agent.latent_dist" : "sphere",
                "state": "finished",
                # "seed": [100, 200, 300]
            },
            "prefix":"sphere",
            "group_by": "config.agent.agent_name",   # config.task_name도 가능
            "select_values": None,
        },
        {
            "filters": {
                "group": "25122605_FINAL_LQLD:meanflowq",      # 실험 그룹명
                "config.horizon_length": 5,       # [중요] horizon이 5인 것만!
                "config.agent.latent_dist" : "sphere",
                "state": "finished",
                # "seed": [100, 200, 300]
            },
            "prefix":"sphere_distill",
            "group_by": "config.agent.agent_name",   # config.task_name도 가능
            "select_values": None,
        },
        {
            "filters": {
                "group": "25122605_FINAL_QC_MFQL:qcmfql",      # 실험 그룹명
                "config.horizon_length": 5,       # [중요] horizon이 5인 것만!
                "config.agent.latent_dist" : "sphere",
                "state": "finished",
                # "seed": [100, 200, 300]
            },
            "prefix":"sphere",
            "group_by": "config.agent.agent_name",  # config.task_name도 가능
            "select_values": None,
        },
        {
            "filters": {
                "group": "25122606_FINAL_QC_FQL:acfql",      # 실험 그룹명
                "config.horizon_length": 5,       # [중요] horizon이 5인 것만!
                "config.agent.latent_dist" : "sphere",
                "state": "finished",
                # "seed": [100, 200, 300]
            },
            "prefix":"sphere",
            "group_by": "config.agent.agent_name",   # config.task_name도 가능
            "select_values": None,
        },
    ],
}
plot_and_save_from_wandb(configs)
# Out:
# Fetching runs with filters: {'group': '25122601_FINAL_MF:meanflow', 'config.horizon_length': 5, 'config.agent.latent_dist': 'sphere', 'state': 'finished'}...
# Found 100 runs.
# 100%|██████████| 100/100 [01:01<00:00,  1.62it/s]
# Fetching runs with filters: {'group': '25122601_FINAL_F:flow', 'config.horizon_length': 5, 'config.agent.latent_dist': 'sphere', 'state': 'finished'}...
# Found 100 runs.
# 100%|██████████| 100/100 [01:02<00:00,  1.59it/s]
# Fetching runs with filters: {'group': '25122605_LQL_FINAL:meanflowq', 'config.horizon_length': 5, 'config.agent.latent_dist': 'sphere', 'state': 'finished'}...
# Found 100 runs.
# 100%|██████████| 100/100 [01:01<00:00,  1.64it/s]
# Fetching runs with filters: {'group': '25122605_FINAL_LQLD:meanflowq', 'config.horizon_length': 5, 'config.agent.latent_dist': 'sphere', 'state': 'finished'}...
# Found 125 runs.
# 100%|██████████| 125/125 [01:15<00:00,  1.65it/s]
# ...

# %%
configs = {
    "WANDB_ENTITY" : "jellyho_",
    "WANDB_PROJECT" : "MFQ",
    "x_key": "_step",
    # "y_key": "latent/z_norm",
    "y_key": "eval/success",
    "title": "OGBench_5_task_results_(Normal)",

    "configs":[
        {
            "filters": {
                "group": "25122601_FINAL_MF:meanflow",      # 실험 그룹명
                "config.horizon_length": 5,       # [중요] horizon이 5인 것만!
                "config.agent.latent_dist" : "normal",
                "state": "finished",             # 완료된 것만 (필요시 주석 해제)
                # "seed": [100, 200, 300]
            },
            "prefix":"normal",
            "group_by": "config.agent.agent_name",  # config.task_name도 가능
            "select_values": None,
        },
        {
            "filters": {
                "group": "25122601_FINAL_F:flow",      # 실험 그룹명
                "config.horizon_length": 5,       # [중요] horizon이 5인 것만!
                "config.agent.latent_dist" : "normal",
                "state": "finished",
                # "seed": [100, 200, 300]
            },
            "prefix":"normal",
            "group_by": "config.agent.agent_name",  # config.task_name도 가능
            "select_values": None,
        },
        {
            "filters": {
                "group": "25122605_LQL_FINAL:meanflowq",      # 실험 그룹명
                "config.horizon_length": 5,       # [중요] horizon이 5인 것만!
                "config.agent.latent_dist" : "normal",
                "state": "finished",
                # "seed": [100, 200, 300]
            },
            "prefix":"normal",
            "group_by": "config.agent.agent_name",   # config.task_name도 가능
            "select_values": None,
        },
        {
            "filters": {
                "group": "25122605_FINAL_LQLD:meanflowq",      # 실험 그룹명
                "config.horizon_length": 5,       # [중요] horizon이 5인 것만!
                "config.agent.latent_dist" : "normal",
                "state": "finished",
                # "seed": [100, 200, 300]
            },
            "prefix":"normal_distill",
            "group_by": "config.agent.agent_name",   # config.task_name도 가능
            "select_values": None,
        },
        {
            "filters": {
                "group": "25122605_FINAL_QC_MFQL:qcmfql",      # 실험 그룹명
                "config.horizon_length": 5,       # [중요] horizon이 5인 것만!
                "config.agent.latent_dist" : "normal",
                "state": "finished",
                # "seed": [100, 200, 300]
            },
            "prefix":"normal",
            "group_by": "config.agent.agent_name",  # config.task_name도 가능
            "select_values": None,
        },
        {
            "filters": {
                "group": "25122606_FINAL_QC_FQL:acfql",      # 실험 그룹명
                "config.horizon_length": 5,       # [중요] horizon이 5인 것만!
                "config.agent.latent_dist" : "normal",
                "state": "finished",
                # "seed": [100, 200, 300]
            },
            "prefix":"normal",
            "group_by": "config.agent.agent_name",   # config.task_name도 가능
            "select_values": None,
        },
    ],
}
plot_and_save_from_wandb(configs)
# Out:
# Fetching runs with filters: {'group': '25122601_FINAL_MF:meanflow', 'config.horizon_length': 5, 'config.agent.latent_dist': 'normal', 'state': 'finished'}...
# Found 100 runs.
# 100%|██████████| 100/100 [01:03<00:00,  1.59it/s]
# Fetching runs with filters: {'group': '25122601_FINAL_F:flow', 'config.horizon_length': 5, 'config.agent.latent_dist': 'normal', 'state': 'finished'}...
# Found 100 runs.
# 100%|██████████| 100/100 [01:01<00:00,  1.61it/s]
# Fetching runs with filters: {'group': '25122605_LQL_FINAL:meanflowq', 'config.horizon_length': 5, 'config.agent.latent_dist': 'normal', 'state': 'finished'}...
# Found 100 runs.
# 100%|██████████| 100/100 [01:01<00:00,  1.62it/s]
# Fetching runs with filters: {'group': '25122605_FINAL_LQLD:meanflowq', 'config.horizon_length': 5, 'config.agent.latent_dist': 'normal', 'state': 'finished'}...
# Found 124 runs.
# 100%|██████████| 124/124 [01:15<00:00,  1.64it/s]
# ...

# %%
configs = {
    "WANDB_ENTITY" : "jellyho_",
    "WANDB_PROJECT" : "MFQ",
    "x_key": "_step",
    # "y_key": "latent/z_norm",
    "y_key": "eval/success",
    "title": "Robomimic_BC_meanflow",

    "configs":[
        {
            "filters": {
                "group": "meanflow:LQL_RM",      # 실험 그룹명
                "config.horizon_length": 5,       # [중요] horizon이 5인 것만!
                "state": "finished",             # 완료된 것만 (필요시 주석 해제)
                # "seed": [100, 200, 300]
            },
            "prefix":"robomimic_meanflow",
            "group_by": "config.task_name",  # config.task_name도 가능
            "select_values": ["lift", "can", "square"],
        },
    ],
}
plot_and_save_from_wandb(configs)
# Out:
# Fetching runs with filters: {'group': 'meanflow:LQL_RM', 'config.horizon_length': 5, 'state': 'finished'}...
# The history saving thread hit an unexpected error (DatabaseError('file is not a database')).History will not be written to the database.
# Found 30 runs.
# 100%|██████████| 30/30 [00:14<00:00,  2.14it/s]
# Plotting group robomimic_meanflow_can
# Plotting group robomimic_meanflow_lift
# Plotting group robomimic_meanflow_square

# %%
configs = {
    "WANDB_ENTITY" : "jellyho_",
    "WANDB_PROJECT" : "MFQ",
    "x_key": "_step",
    # "y_key": "latent/z_norm",
    "y_key": "eval/success",
    "title": "Robomimic_BC_flow",

    "configs":[
        {
            "filters": {
                "group": "flow:LQL_RM",      # 실험 그룹명
                "config.horizon_length": 5,       # [중요] horizon이 5인 것만!
                # "config.agent.latent_dist" : "sphere",
                "state": "finished",             # 완료된 것만 (필요시 주석 해제)
                # "seed": [100, 200, 300]
            },
            "prefix":"robomimic_flow",
            "group_by": "config.task_name",  # config.task_name도 가능
            "select_values": ["lift", "can", "square"],
        },
    ],
}
plot_and_save_from_wandb(configs)
# Out:
# Fetching runs with filters: {'group': 'flow:LQL_RM', 'config.horizon_length': 5, 'state': 'finished'}...
# Found 20 runs.
# 100%|██████████| 20/20 [00:09<00:00,  2.15it/s]
# Plotting group robomimic_flow_can
# Plotting group robomimic_flow_lift
# Plotting group robomimic_flow_square

# %%
configs = {
    "WANDB_ENTITY" : "jellyho_",
    "WANDB_PROJECT" : "MFQ",
    "x_key": "_step",
    # "y_key": "latent/z_norm",
    "y_key": "eval/success",
    "title": "Robomimic_QCFQL",
    "folder": "plots",

    "configs":[
        {
            "filters": {
                "group": "qcfql:QCFQL_RM",      # 실험 그룹명
                "config.horizon_length": 5,       # [중요] horizon이 5인 것만!
                # "config.agent.latent_dist" : "sphere",
                "state": "finished",             # 완료된 것만 (필요시 주석 해제)
                "config.agent.alpha": 10000.0
            },
            "prefix":"robomimic",
            "group_by": "config.task_name",  # config.task_name도 가능
            "select_values": ["lift", "can", "square"],
        },
    ],
}
plot_and_save_from_wandb(configs)
# Out:
# Fetching runs with filters: {'group': 'qcfql:QCFQL_RM', 'config.horizon_length': 5, 'state': 'finished', 'config.agent.alpha': 10000.0}...
# Found 17 runs.
# 100%|██████████| 17/17 [00:07<00:00,  2.39it/s]
# Plotting group robomimic_can
# Plotting group robomimic_lift
# Plotting group robomimic_square
